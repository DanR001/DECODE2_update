# %%
import numpy as np
import matplotlib.pyplot as plt
from SFRF import *

# %%
def nearest(vector,value):
    res=(np.abs(vector - value)).argmin()
    return res

# %%
nred_lapi, red_lapi, nsfr_lapi, sfrlog_lapi, phisfr_lapi, phisfr_etg_lapi, phisfr_ltg_lapi = SFR_function_UV_IR_Mancuso_Lapi()

# %%
plt.plot(sfrlog_lapi, np.log10(phisfr_lapi[:,nearest(red_lapi,0)]))
plt.ylim(-8,-1)
# Out:
# (-8.0, -1.0)
